# %% [markdown]
# # South German Credit
#
# ## about the dataset:
# https://archive.ics.uci.edu/dataset/522/south+german+credit

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans
from sklearn.metrics import roc_curve , auc
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.ensemble import VotingClassifier , StackingClassifier # ensemble
import matplotlib.pyplot as plt 
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier,  StackingClassifier
from sklearn.metrics import classification_report, confusion_matrix, precision_score, accuracy_score, roc_curve, precision_recall_curve , auc , make_scorer
from sklearn import svm
from math import sqrt




import warnings
warnings.simplefilter('ignore')

# %matplotlib inline

# %%
# para visualizar todas as colunas do dataframe
pd.set_option('display.max_columns', None)

# %%
# mudando o diretório 

import os

os.getcwd()
# Out:
# '/home/marcos_well/Área de Trabalho/Projetos_Python/GitHub projects/Data-Science'

# %%
os.chdir('/home/marcos_well/Área de Trabalho/Projetos_Python/data')

# %%
df_original = pd.read_csv('SouthGermanCredit.asc', sep = ' ')

# %%
df_original.head()
# Out:
#    laufkont  laufzeit  moral  verw  hoehe  sparkont  beszeit  rate  famges  \
# 0         1        18      4     2   1049         1        2     4       2
# 1         1         9      4     0   2799         1        3     2       3
# 2         2        12      2     9    841         2        4     2       2
# 3         1        12      4     0   2122         1        3     3       3
# 4         1        12      4     0   2171         1        3     4       3
#
#    buerge  wohnzeit  verm  alter  weitkred  wohn  bishkred  beruf  pers  \
# 0       1         4     2     21         3     1         1      3     2
# 1       1         2     1     36         3     1         2      3     1
# 2       1         4     1     23         3     1         1      2     2
# 3       1         2     1     39         3     1         2      2     1
# 4       1         4     2     38         1     2         2      2     2
#
#    telef  gastarb  kredit
# 0      1        2       1
# 1      1        2       1
# ...

# %%
df_original.shape
# Out:
# (1000, 21)

# %%
df = df_original

# %%
# Verificando os valores faltantes

print(df.isnull().values.any())
print(df.isna().values.any())
# Out:
# False
# False

# %%
# renomeando as variaveis 

df.columns = ['status', 'duration', 'credit_history', 'purpose', 'amount',  'savings', 'employment_duration'
              , 'installment_rate', 'personal_status_sex', 'other_debtors', 'present_residence', 'property'
              ,  'age', 'other_installment_plans', 'housing', 'number_credits', 'job', 'people_liable'
              , 'telephone',  'foreign_worker', 'credit_risk']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   status                   1000 non-null   int64
#  1   duration                 1000 non-null   int64
#  2   credit_history           1000 non-null   int64
#  3   purpose                  1000 non-null   int64
#  4   amount                   1000 non-null   int64
#  5   savings                  1000 non-null   int64
#  6   employment_duration      1000 non-null   int64
#  7   installment_rate         1000 non-null   int64
#  8   personal_status_sex      1000 non-null   int64
#  9   other_debtors            1000 non-null   int64
#  10  present_residence        1000 non-null   int64
#  11  property                 1000 non-null   int64
#  12  age                      1000 non-null   int64
#  13  other_installment_plans  1000 non-null   int64
# ...

# %%
df.head()
# Out:
#    status  duration  credit_history  purpose  amount  savings  \
# 0       1        18               4        2    1049        1
# 1       1         9               4        0    2799        1
# 2       2        12               2        9     841        2
# 3       1        12               4        0    2122        1
# 4       1        12               4        0    2171        1
#
#    employment_duration  installment_rate  personal_status_sex  other_debtors  \
# 0                    2                 4                    2              1
# 1                    3                 2                    3              1
# 2                    4                 2                    2              1
# 3                    3                 3                    3              1
# 4                    3                 4                    3              1
#
#    present_residence  property  age  other_installment_plans  housing  \
# ...

# %%
# plotando um histrograma das variaveis 

df.hist()

plt.gcf().set_size_inches(25,15)

# %%
# excluindo uma coluna
#df.drop('personal_status_sex', axis =1 , inplace = True) 
df.drop('telephone', axis =1, inplace = True)

# %%
# limpando os NaNs

df.dropna(axis=0, inplace = True)

# %% [markdown]
# ## transformando variaveis constantes em intervalos

# %%
# separando a idade 'age' em intervalos 
age_int = list(range(df.age.min(), df.age.max()+10, 10)) # dividindo de 10 em 10

# criando o nome dos intervalos
nome_int = [f'age_i{i}' for i in range(len(age_int)-1)]

# atribuindo ao dataframe
df['age_int'] = pd.cut(df.age, age_int, labels = nome_int, include_lowest = True)

###########################################################################################
# separando a idade 'duration' em intervalos 
duration_int = list(range(df.duration.min(), df.duration.max()+12, 12)) # dividindo de 12 em 12

# criando o nome dos intervalos
nome_int2 = [f'duration_i{i}' for i in range(len(duration_int)-1)]

# atribuindo ao dataframe
df['duration_int'] = pd.cut(df.duration, duration_int, labels = nome_int2, include_lowest = True)

###########################################################################################
# separando a idade 'amount' em intervalos 
amount_int = list(range(df.amount.min(), df.amount.max()+3000, 3000)) # dividindo de 3k em 3k

# criando o nome dos intervalos
nome_int3 = [f'amount_i{i}' for i in range(len(amount_int)-1)]

# atribuindo ao dataframe
df['amount_int'] = pd.cut(df.amount, amount_int, labels = nome_int3, include_lowest = True)

# %%
# removendo a variavel 'age'
df = df.drop(['age', 'duration', 'amount'], axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   status                   1000 non-null   int64
#  1   credit_history           1000 non-null   int64
#  2   purpose                  1000 non-null   int64
#  3   savings                  1000 non-null   int64
#  4   employment_duration      1000 non-null   int64
#  5   installment_rate         1000 non-null   int64
#  6   personal_status_sex      1000 non-null   int64
#  7   other_debtors            1000 non-null   int64
#  8   present_residence        1000 non-null   int64
#  9   property                 1000 non-null   int64
#  10  other_installment_plans  1000 non-null   int64
#  11  housing                  1000 non-null   int64
#  12  number_credits           1000 non-null   int64
#  13  job                      1000 non-null   int64
# ...

# %%
# convertendo dtype de category em numerico 
categorias = {'age_int': {'age_i0': 0, 'age_i1': 1, 'age_i2': 2, 'age_i4': 4, 'age_i3': 3, 'age_i5': 5}}
df.replace(categorias, inplace = True)

#################################################
# convertendo dtype de category para int
categorias2 = {'duration_int': {'duration_i0': 0, 'duration_i1': 1, 'duration_i2': 2, 'duration_i4': 4, 'duration_i3': 3, 'duration_i5': 5,'duration_i6': 6}}
df.replace(categorias2, inplace = True)

#################################################
# convertendo dtype de category para int
categorias3 = {'amount_int': {'amount_i0': 0, 'amount_i1': 1, 'amount_i2': 2, 'amount_i4': 4, 'amount_i3': 3, 'amount_i5': 5,'amount_i6': 6}}
df.replace(categorias3, inplace = True)

# %%
#transformando em int
df['age_int'] = np.array(df['age_int'],dtype='int')
df['duration_int'] = np.array(df['duration_int'],dtype='int')
df['amount_int'] = np.array(df['amount_int'],dtype='int')

# %%
df.columns
# Out:
# Index(['status', 'credit_history', 'purpose', 'savings', 'employment_duration',
#        'installment_rate', 'personal_status_sex', 'other_debtors',
#        'present_residence', 'property', 'other_installment_plans', 'housing',
#        'number_credits', 'job', 'people_liable', 'foreign_worker',
#        'credit_risk', 'age_int', 'duration_int', 'amount_int'],
#       dtype='object')

# %%
# plotando um histrograma das variaveis 

df.hist()

plt.gcf().set_size_inches(25,15)

# %% [markdown]
# # Label Encoding

# %%
# Ajustando a variavel com o Label Encoder para ter 0 ou 1 

# Ajustando dando os valores do label
label_encoder = LabelEncoder()

foreign_encoder = label_encoder.fit_transform(df.foreign_worker)
foreign_encoder

# atribuindo ao data frame
df['foreign_encoder'] = foreign_encoder

# excluindo a coluna do calculo das medias da crosstab
df = df.drop('foreign_worker', axis=1)

# %%
# Analisando a nova variavel
df['foreign_encoder'].value_counts()
# Out:
# foreign_encoder
# 1    963
# 0     37
# Name: count, dtype: int64

# %% [markdown]
# # <b> Kmeans </b>

# %% [markdown]
# - O objetivo é criar sub grupos para que posteriormente possamos analisar indidualmente cada um.

# %% [markdown]
# ## Avaliação do número de clusters necessários

# %%
# variáveis que serão utilizadas no kmeans , utilizando algumas das variaveis padrão da base de dados
df_km = df[['status', 'duration_int', 'credit_history', 'purpose', 'amount_int',  'savings', 'age_int',
            'employment_duration','other_debtors', 'property', 'number_credits']]

# %%
min_clusters = 2
max_clusters = 20
inertias = np.zeros(shape = (max_clusters - min_clusters+1, ))

# %%
for i in range(min_clusters, max_clusters + 1):
    km = KMeans(n_clusters= i)
    km.fit(df_km)
    inertias[i - min_clusters] = km.inertia_

# %%
plt.figure(figsize = (10,6))
plt.plot(range(min_clusters, max_clusters + 1 ), inertias, color = 'b')
plt.title('Avaliação do numero de clusters')
plt.xlabel('# de clusters')
plt.ylabel('Soma da distancia quadrada');
plt.grid();

# %%
# Treinamento do Kmeans 

kmodel = KMeans(n_clusters= 6, random_state=42)
clusters = kmodel.fit(df_km)

# %%
# Atribuindo ao Data Frame 
df['Cluster'] = pd.DataFrame(clusters.labels_, columns = ['Cluster'])

# %%
# relação com o alvo 
pd.crosstab(df['Cluster'], df['credit_risk'])
# Out:
# credit_risk    0    1
# Cluster
# 0             24  183
# 1             31   42
# 2            119  120
# 3             33  175
# 4             53  102
# 5             40   78

# %%
df.tail()
# Out:
#      status  credit_history  purpose  savings  employment_duration  \
# 995       1               2        3        1                    3
# 996       1               2        0        1                    5
# 997       4               4        0        5                    5
# 998       2               2        3        5                    1
# 999       1               2        2        5                    5
#
#      installment_rate  personal_status_sex  other_debtors  present_residence  \
# 995                 2                    3              1                  4
# 996                 4                    3              2                  1
# 997                 4                    3              1                  4
# 998                 2                    3              1                  1
# 999                 4                    3              1                  4
#
#      property  other_installment_plans  housing  number_credits  job  \
# ...

# %% [markdown]
# # <b>Primeiro modelo </b>

# %% [markdown]
# # RandomForestClassifier

# %% [markdown]
# ## Seprando os dados para teste e treinamento

# %%
# separando os dados com as variavesi em x e o alvo y 

x = df.drop('credit_risk', axis = 1)
y = df['credit_risk']

# separando entre treinamento e teste 

x_train1, x_test1, y_train1, y_test1 = train_test_split(x, y, test_size = 0.5)

# %%
# treiando o modelo 

rf_class = RandomForestClassifier(bootstrap = True
                               , criterion = 'gini', max_depth = 3
                               , max_features = 'sqrt', min_samples_leaf = 1
                               , min_samples_split= 2, n_estimators=1000 
                               , n_jobs= -1, oob_score= True)

rf_class.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=3, n_estimators=1000, n_jobs=-1,
#                        oob_score=True)

# %% [markdown]
# ## Avaliação do Modelo

# %%
# Predições para o treinamento e teste

y_pred_train_rf = rf_class.predict(x_train)
y_pred_test_rf = rf_class.predict(x_test)

# Return -1 for outliers and 1 for inliers

# %%
# Matriz de Confusão - test
print(confusion_matrix(y_test1, y_pred_test_rf))
print()
print('-----------------------------------------------------------')
print()
print(classification_report(y_test1, y_pred_test_rf))
# Out:
# [[  7 148]
#  [ 17 328]]
#
# -----------------------------------------------------------
#
#               precision    recall  f1-score   support
#
#            0       0.29      0.05      0.08       155
#            1       0.69      0.95      0.80       345
#
#     accuracy                           0.67       500
#    macro avg       0.49      0.50      0.44       500
# weighted avg       0.57      0.67      0.58       500

# %% [markdown]
# # <b>SVM</b>

# %% [markdown]
# # Segundo Treinamento utilizando a SVM

# %%
x2 = df.drop('credit_risk', axis = 1)
y2 = df['credit_risk']

# separando entre treinamento e teste 

x_train2, x_test2, y_train2, y_test2 = train_test_split(x2, y2, test_size = 0.5)

# %%
# Treinamneto do modelo

# Kernels : rbf, poly, linear 

svm1 = svm.SVC(kernel = 'rbf' , gamma = 'auto', max_iter = 2000 , random_state= 42)

# trianmento do modelo 
svm1.fit(x_train2, y_train2)
# Out:
# SVC(gamma='auto', max_iter=2000, random_state=42)

# %% [markdown]
#  ## Avaliação SVM

# %%
# fazendo a predição da base de treinamento e teste

y_pred_train_svm = svm1.predict(x_train2)
y_pred_test_svm = svm1.predict(x_test2)

# %%
# Calculando a ROC e o Gini - Treinamento
fpr_train2, tpr_train2, thresholds_train2 = roc_curve(y_train2, y_pred_train_svm)
roc_auc_train2 = auc(fpr_train2, tpr_train2)

print('AUC -  Treinamento : %f' % roc_auc_train2)
print('Gini -  Treinamento : ', round(2*roc_auc_train2-1,2))
print()

# Calculando a ROC e o Gini - Teste
fpr_test2, tpr_test2, thresholds_test_rf = roc_curve(y_test2, y_pred_test_svm)
roc_auc_test2 = auc(fpr_test2, tpr_test2)

print('AUC -  Test : %f' % roc_auc_test2)
print('Gini -  Test : ', round(2*roc_auc_test2-1,2))
print()
# Out:
# AUC -  Treinamento : 0.784385
# Gini -  Treinamento :  0.57
#
# AUC -  Test : 0.666877
# Gini -  Test :  0.33

# %%
# Matriz de Confusão - test
print(confusion_matrix(y_test2, y_pred_test_svm))
print()
print('-----------------------------------------------------------')
print()
print(classification_report(y_test2, y_pred_test_svm))
# Out:
# [[ 68  77]
#  [ 48 307]]
#
# -----------------------------------------------------------
#
#               precision    recall  f1-score   support
#
#            0       0.59      0.47      0.52       145
#            1       0.80      0.86      0.83       355
#
#     accuracy                           0.75       500
#    macro avg       0.69      0.67      0.68       500
# weighted avg       0.74      0.75      0.74       500

# %% [raw]
# O modelo erra bastante da classificação do '1' que são os credit_risk 'good'

# %% [markdown]
# # Montando um ensemble dos modelos anteriores

# %% [markdown]
# # <b> Ensemble Model </b>

# %%
x3 = df.drop('credit_risk', axis = 1)
y3 = df['credit_risk']

# separando entre treinamento e teste 

x_train3, x_test3, y_train3, y_test3 = train_test_split(x3, y3, test_size = 0.5)

# %%
# São utilizados os mesmo modelos acima com um final estimator sendo um LogisticRegression

models = [
             ('RandomForestClassifier', RandomForestClassifier(bootstrap = True
                               , criterion = 'gini', max_depth = 3
                               , max_features = 'sqrt', min_samples_leaf = 1
                               , min_samples_split= 2, n_estimators=1000 
                               , n_jobs= -1, oob_score= True))
             , ('svm' , svm.SVC(kernel = 'rbf', probability=True, gamma = 'auto', max_iter = 2000 , random_state= 42))
           ]

#Stacking - passthrough
ensemble_stacking_pt = StackingClassifier(models, LogisticRegression(), passthrough= True)
ensemble_soft = VotingClassifier(models, voting= 'soft')


ensemble_soft.fit(x_train3, y_train3)
ensemble_stacking_pt.fit(x_train3, y_train3)
# Out:
# StackingClassifier(estimators=[('RandomForestClassifier',
#                                 RandomForestClassifier(max_depth=3,
#                                                        n_estimators=1000,
#                                                        n_jobs=-1,
#                                                        oob_score=True)),
#                                ('svm',
#                                 SVC(gamma='auto', max_iter=2000,
#                                     probability=True, random_state=42))],
#                    final_estimator=LogisticRegression(), passthrough=True)

# %%
print('Soft Voting: {}'.format(round(accuracy_score(y_test3, ensemble_soft.predict(x_test3))*100, 2)))
print('Stacking - passthrough: {}'.format(round(accuracy_score(y_test3, ensemble_stacking_pt.predict(x_test3))*100, 2)))
print('Random Florest: {}'.format(round(accuracy_score(y_test3, rf_class.predict(x_test3))*100, 2)))
print('SVM: {}'.format(round(accuracy_score(y_test3, svm1.predict(x_test3))*100, 2)))
# Out:
# Soft Voting: 74.8
# Stacking - passthrough: 75.0
# Random Florest: 75.6
# SVM: 80.2

# %% [markdown]
# # Avaliação da estabilidade dos modelos

# %%
print('Stacking Train: {}'.format(round(accuracy_score(y_train3, ensemble_soft.predict(x_train3))*100, 2)))
print('Stacking Test: {}'.format(round(accuracy_score(y_test3, ensemble_soft.predict(x_test3))*100, 2)))
print('Taxa Tr/Te: {}'.format(round( # diferença entre performace do treino e do teste , quanto menor mais proximo treinamento e teste - mais estavel
              (accuracy_score(y_train3, ensemble_soft.predict(x_train3))/accuracy_score(y_test3, ensemble_soft.predict(x_test3))-1)*100, 2)))

print('')
print('Stacking passthrough Train: {}'.format(round(accuracy_score(y_train3, ensemble_stacking_pt.predict(x_train3))*100, 2)))
print('Stacking passthrough Test: {}'.format(round(accuracy_score(y_test3, ensemble_stacking_pt.predict(x_test3))*100, 2)))
print('Taxa Tr/Te: {}'.format(round( # diferença entre performace do treino e do teste , quanto menor mais proximo treinamento e teste - mais estavel
              (accuracy_score(y_train3, ensemble_stacking_pt.predict(x_train3))/accuracy_score(y_test3, ensemble_stacking_pt.predict(x_test3))-1)*100, 2)))

print('')
print('Random Florest Train: {}'.format(round(accuracy_score(y_train3, rf_class.predict(x_train3))*100, 2)))
print('Random Florest Test: {}'.format(round(accuracy_score(y_test3, rf_class.predict(x_test3))*100, 2)))
print('Taxa Tr/Te: {}'.format(round( # diferença entre performace do treino e do teste , quanto menor mais proximo treinamento e teste - mais estavel
              (accuracy_score(y_train3, rf_class.predict(x_train3))/accuracy_score(y_test3, rf_class.predict(x_test3))-1)*100, 2)))

print('')
print('SVM Train: {}'.format(round(accuracy_score(y_train3, svm1.predict(x_train3))*100, 2)))
print('SVM Test: {}'.format(round(accuracy_score(y_test3, svm1.predict(x_test3))*100, 2)))
print('Taxa Tr/Te: {}'.format(round( # diferença entre performace do treino e do teste , quanto menor mais proximo treinamento e teste - mais estavel
              (accuracy_score(y_train3, svm1.predict(x_train3))/accuracy_score(y_test3, svm1.predict(x_test3))-1)*100, 2)))
# Out:
# Stacking Train: 85.2
# Stacking Test: 74.8
# Taxa Tr/Te: 13.9
#
# Stacking passthrough Train: 78.2
# Stacking passthrough Test: 75.0
# Taxa Tr/Te: 4.27
#
# Random Florest Train: 72.6
# Random Florest Test: 75.6
# Taxa Tr/Te: -3.97
#
# SVM Train: 80.0
# SVM Test: 80.2
# Taxa Tr/Te: -0.25

# %% [raw]
# O modelo que se mostra mais estável é o SVM.
# O ideal seria trabalhar um modelo para cada um dos CLusters
# , porém como temos poucos registros não será possível.
